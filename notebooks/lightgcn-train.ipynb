# %%
import os                                                                                                                                      
os.system("git clone --depth=1 https://github.com/JacKoz7/LightGCN-Recommender /tmp/lgcn")                                                     
os.system("cp -r /tmp/lgcn/src .")
# Out:
# Cloning into '/tmp/lgcn'...
# 0

# %%
# !python src/train.py
# Out:
# Starting training...
#
# Device: cuda
#
# Loading dataset from /kaggle/input/datasets/jackkozx/gowalla-dataset ...
# Training LightGCN — layers=3, dim=64, lr=0.001, λ=0.0001, device=cuda
# Batches per epoch: 791  (810,128 interactions / batch_size 1024)
#
#  Epoch |     Loss |  Recall@20 |   NDCG@20
# ---------------------------------------------
#     10 |   0.0723 |     0.1192 |    0.1041 ←
#     20 |   0.0505 |     0.1334 |    0.1155 ←
#     30 |   0.0415 |     0.1424 |    0.1228 ←
#     40 |   0.0358 |     0.1477 |    0.1274 ←
#     50 |   0.0319 |     0.1518 |    0.1309 ←
#     60 |   0.0293 |     0.1559 |    0.1338 ←
#     70 |   0.0272 |     0.1584 |    0.1359 ←
#     80 |   0.0256 |     0.1615 |    0.1382 ←
#     90 |   0.0244 |     0.1633 |    0.1397 ←
#    100 |   0.0234 |     0.1648 |    0.1412 ←
#    110 |   0.0224 |     0.1666 |    0.1427 ←
#    120 |   0.0219 |     0.1679 |    0.1435 ←
#    130 |   0.0213 |     0.1685 |    0.1444 ←
#    140 |   0.0208 |     0.1695 |    0.1449 ←
#    150 |   0.0205 |     0.1708 |    0.1458 ←
#    160 |   0.0200 |     0.1708 |    0.1458 ←
#    170 |   0.0195 |     0.1711 |    0.1464 ←
#    180 |   0.0195 |     0.1723 |    0.1472 ←
#    190 |   0.0192 |     0.1727 |    0.1474 ←
#    200 |   0.0190 |     0.1728 |    0.1476 ←
#    210 |   0.0188 |     0.1728 |    0.1478
#    220 |   0.0190 |     0.1734 |    0.1482 ←
#    230 |   0.0186 |     0.1741 |    0.1489 ←
#    240 |   0.0187 |     0.1745 |    0.1491 ←
#    250 |   0.0184 |     0.1747 |    0.1494 ←
#    260 |   0.0182 |     0.1754 |    0.1496 ←
#    270 |   0.0183 |     0.1753 |    0.1495
#    280 |   0.0182 |     0.1758 |    0.1501 ←
#    290 |   0.0181 |     0.1757 |    0.1499
#    300 |   0.0179 |     0.1762 |    0.1503 ←
#    310 |   0.0180 |     0.1768 |    0.1505 ←
#    320 |   0.0179 |     0.1765 |    0.1504
#    330 |   0.0178 |     0.1768 |    0.1507 ←
#    340 |   0.0177 |     0.1768 |    0.1507
#    350 |   0.0177 |     0.1764 |    0.1505
#    360 |   0.0178 |     0.1768 |    0.1506 ←
#    370 |   0.0175 |     0.1770 |    0.1509 ←
#    380 |   0.0177 |     0.1772 |    0.1508 ←
#    390 |   0.0177 |     0.1772 |    0.1507
#    400 |   0.0177 |     0.1773 |    0.1510 ←
# ---------------------------------------------
#
# Best  Recall@20 : 0.1773   (paper: 0.1823)
# Best  NDCG@20   : 0.1510   (paper: 0.1554)
